# %% [markdown]
# # Greedy Breadth First Search
# * It is a search algorithm that expands the node that is closest to the goal, as estimated by a heuristic function.
# * It uses a priority queue to keep track of nodes to be explored, prioritizing those with the lowest heuristic cost.
#
# We know that it will have to make a move, where it can make a move, and what the results are of making these moves.
