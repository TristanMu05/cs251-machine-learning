# %% [markdown]
# Agent: the ai can percieve its environment and make actons on its
# State: the configuration of that perticular environment
# Goal State: the solved state of the problem
# Unsolved State: requires actions to solve the problem
# Actions: a choiceor decision an agent can make on the current state. typically represented as functions
# transition function: when an action is made it returns the new state
# path cost: we cannot examine every single possibility, so we want to factor in the path cost for time and quality

# %% [markdown]
# Depth first search via agacency matrix
#     stack LIFO
#     find a path from A to E
#
# 1) construct a stack
# 2) push starting node
# 3) loop:
#     *

# %%
class Node:
    def __init__(self, val, children):
        self.val = val
        self.children = [] 
    def getVal(self):
        return self.val
    def setVal(self, val):
        self.val = val
    


def main():


if __name__ == "__main__":
    main()

# %% [markdown]
# *** Breaadth first search
# Queues
#
# * expands the shallowest ode in the graph
# * queue is the data structure
# * employs the first in first out
#
# * searches tree level by level
# * not automatically backtracking

# %% [markdown]
# *** Homework practice
# * code a java program that simuates traveing between train stations
# the stations and their connections should be represented using an adjacency matrix
# use a astack to implement a depth first search (DFS)
# print the travel log froma  starting station to an ending station
